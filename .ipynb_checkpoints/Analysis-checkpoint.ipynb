# %%
import pandas as pd
import glob

import statsmodels.api as sm

# %% [markdown]
# ## Read Data

# %%
# Add past year's data
path = 'C:/Users/sutantoy/Downloads/rooroo/csv'
all_files = glob.glob(path + "/*.csv")

li = []

for file in all_files:
    file_df = pd.read_csv(file)
    
    area = file.split('\\')[1].replace('.csv','')
    file_df['area'] = area
    
    li.append(file_df)

df = pd.concat(li, axis=0, ignore_index=True)
common_cols = ['block', 'street name', 'lease commence year', 'resale registration date']
# Lease commentment year corr to remaining lease
df.drop(columns=common_cols, inplace=True)

# Add even more historical data
hist_path = 'C:/Users/sutantoy/Downloads/rooroo/Jan2017ToOct2020'
hist_all_files = glob.glob(hist_path + "/*.csv")

hist_li = []

for file in hist_all_files:
    file_df = pd.read_csv(file)
    
    area = file.split('\\')[1].replace('.csv','')
    file_df['area'] = area
    
    hist_li.append(file_df)

hist_df = pd.concat(hist_li, axis=0, ignore_index=True)
hist_df.drop(columns=common_cols + ['rank town', 'flat type'], inplace=True)

df = df.append(hist_df)
del hist_df

mapping = {'01 to 03': 2, 
           '04 to 06': 5, 
           '07 to 09': 8, 
           '10 to 12': 11, 
           '13 to 15': 14, 
           '16 to 18': 17, 
           '19 to 21': 20,
           '22 to 24': 23,
           '25 to 27': 26,
           '28 to 30': 29,
           '31 to 33': 36,
           '34 to 36': 35,
           '37 to 39': 38,
           '40 to 42': 41,
           '43 to 45': 44,
           '46 to 48': 47,
           '01 TO 03': 2, 
           '04 TO 06': 5, 
           '07 TO 09': 8, 
           '10 TO 12': 11, 
           '13 TO 15': 14, 
           '16 TO 18': 17, 
           '19 TO 21': 20,
           '22 TO 24': 23,
           '25 TO 27': 26,
           '28 TO 30': 29,
           '31 TO 33': 36,
           '34 TO 36': 35,
           '37 TO 39': 38,
           '40 TO 42': 41,
           '43 TO 45': 44,
           '46 TO 48': 47}
df['storey'] = df['storey'].map(mapping)

df = df[df['storey'] >= 16]

display(df.head())
print(df.shape)
# Out:
#      storey  floor area (sqm) flat model  lease commence year  \
# 74       26                70    Model A                 2012
# 225      26                70    Model A                 2012
# 299      17                67    Model A                 2015
# 342      20                67    Model A                 2015
# 344      29                70    Model A                 2012
#
#      remaining lease (yr)  resale price ($)        area
# 74                  90.00            530000  Ang Mo Kio
# 225                 90.33            543000  Ang Mo Kio
# 299                 93.67            455000  Ang Mo Kio
# 342                 93.75            473000  Ang Mo Kio
# 344                 90.58            510000  Ang Mo Kio
# (863, 7)

# %%
df.corr()
# Out:
#                         storey  floor area (sqm)  lease commence year  \
# storey                1.000000         -0.098248             0.544918
# floor area (sqm)     -0.098248          1.000000            -0.097243
# lease commence year   0.544918         -0.097243             1.000000
# remaining lease (yr)  0.541868         -0.095300             0.997611
# resale price ($)      0.609092         -0.043387             0.825618
#
#                       remaining lease (yr)  resale price ($)
# storey                            0.541868          0.609092
# floor area (sqm)                 -0.095300         -0.043387
# lease commence year               0.997611          0.825618
# remaining lease (yr)              1.000000          0.816810
# resale price ($)                  0.816810          1.000000

# %%
x = df.drop(columns = 'resale price ($)')
x = pd.get_dummies(x)
y = df[['resale price ($)']]

# %%
lr = sm.OLS(y,x)
lr.fit().summary2().tables
# Out:
# [                     0                 1                    2           3
#  0               Model:               OLS      Adj. R-squared:       0.897
#  1  Dependent Variable:  resale price ($)                 AIC:  20634.4714
#  2                Date:  2021-11-26 16:33                 BIC:  20724.9193
#  3    No. Observations:               863      Log-Likelihood:     -10298.
#  4            Df Model:                18         F-statistic:       418.4
#  5        Df Residuals:               844  Prob (F-statistic):        0.00
#  6           R-squared:             0.899               Scale:  1.3871e+09,
#                                       Coef.      Std.Err.          t  \
#  storey                        1.858997e+03  2.320993e+02   8.009489
#  floor area (sqm)              4.345430e+03  3.428904e+02  12.672941
#  lease commence year           1.393882e+04  1.053771e+03  13.227556
#  remaining lease (yr)         -9.591268e+03  1.023620e+03  -9.369946
#  flat model_Dbss              -1.680368e+07  1.271117e+06 -13.219625
#  flat model_Improved          -1.688638e+07  1.267360e+06 -13.324056
#  flat model_Model A           -1.684342e+07  1.270513e+06 -13.257179
#  flat model_New Generation    -1.689249e+07  1.269210e+06 -13.309452
#  flat model_Premium Apartment -1.681658e+07  1.271047e+06 -13.230494
#  flat model_Standard          -1.690775e+07  1.266768e+06 -13.347158
#  area_Ang Mo Kio              -1.017602e+07  7.606920e+05 -13.377313
#  area_Bedok                   -1.015270e+07  7.606658e+05 -13.347129
#  area_Bukit Merah             -1.007402e+07  7.615125e+05 -13.228967
#  area_Central Area            -9.990686e+06  7.616569e+05 -13.117043
#  area_Clementi                -1.015060e+07  7.615370e+05 -13.329097
#  area_Hougang                 -1.027037e+07  7.623389e+05 -13.472177
#  area_Marine Parade           -1.000224e+07  7.618860e+05 -13.128259
#  area_Queenstown              -1.006823e+07  7.620348e+05 -13.212304
#  area_Toa Payoh               -1.014730e+07  7.619137e+05 -13.318174
#  area_Whampoa                 -1.011814e+07  7.618843e+05 -13.280417
#
#                                       P>|t|        [0.025        0.975]
#  storey                        3.812657e-15  1.403438e+03  2.314557e+03
#  floor area (sqm)              8.107154e-34  3.672412e+03  5.018448e+03
#  lease commence year           1.956666e-36  1.187050e+04  1.600714e+04
#  remaining lease (yr)          6.455047e-20 -1.160041e+04 -7.582127e+03
#  flat model_Dbss               2.135324e-36 -1.929860e+07 -1.430876e+07
#  flat model_Improved           6.740225e-37 -1.937393e+07 -1.439883e+07
#  flat model_Model A            1.411466e-36 -1.933716e+07 -1.434968e+07
#  flat model_New Generation     7.922430e-37 -1.938367e+07 -1.440131e+07
#  flat model_Premium Apartment  1.894349e-36 -1.931136e+07 -1.432179e+07
#  flat model_Standard           5.218567e-37 -1.939414e+07 -1.442137e+07
#  area_Ang Mo Kio               3.735215e-37 -1.166909e+07 -8.682945e+06
#  area_Bedok                    5.220227e-37 -1.164572e+07 -8.659686e+06
#  area_Bukit Merah              1.926497e-36 -1.156870e+07 -8.579342e+06
#  area_Central Area             6.590235e-36 -1.148565e+07 -8.495722e+06
#  area_Clementi                 6.374392e-37 -1.164533e+07 -8.655871e+06
#  area_Hougang                  1.300335e-37 -1.176667e+07 -8.774063e+06
#  area_Marine Parade            5.827834e-36 -1.149765e+07 -8.506823e+06
#  area_Queenstown               2.314596e-36 -1.156394e+07 -8.572529e+06
#  area_Toa Payoh                7.193688e-37 -1.164277e+07 -8.651831e+06
#  area_Whampoa                  1.092069e-36 -1.161355e+07 -8.622730e+06  ,
#                  0       1                  2                     3
#  0        Omnibus:  32.771     Durbin-Watson:                 1.902
#  1  Prob(Omnibus):   0.000  Jarque-Bera (JB):                51.229
#  2           Skew:  -0.318          Prob(JB):                 0.000
#  3       Kurtosis:   4.009     Condition No.:  16583714178001410048]
